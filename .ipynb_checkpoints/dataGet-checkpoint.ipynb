# %%
import numpy as np
import pandas as pd
from src_code.dbConnector import *

# %%
import socket
server = f'{socket.gethostname()}.local'
username = 
password = 
driver = '{ODBC Driver 17 for SQL Server}'

# %%
investingData = dbJob(server, "investing_com_data", username, password, driver)
usd_vnd = investingData.getData("USD_VND_rawData")
vnindex = investingData.getData("VNINDEX_rawData")
brent_oil = investingData.getData("XBR_USD_rawData")
gold_price = investingData.getData("XAU_USD_rawData")

# %%
debtData = dbJob(server, "debt_data", username, password, driver)
tpcpVN = debtData.getData("tpcp_yield_scndMkt_rawData")

# %%
usd_vnd = usd_vnd[['date', 'USDVND_close']]
usd_vnd = usd_vnd.set_index('date')
usd_vnd.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
vnindex = vnindex[['date', 'VN_close']]
vnindex = vnindex.set_index('date')
vnindex.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
brent_oil = brent_oil[['date', 'XBRUSD_close']]
brent_oil = brent_oil.set_index('date')
brent_oil.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
gold_price = gold_price[['date', 'XAUUSD_close']]
gold_price = gold_price.set_index('date')
gold_price.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
tpcpVN = tpcpVN[['date', '10y_yield']]
tpcpVN = tpcpVN.set_index('date')
tpcpVN.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
data = pd.concat([usd_vnd, brent_oil, gold_price, vnindex, tpcpVN], axis = 1)

# %%
data.dropna().to_csv('./data/data_use.csv')

# %%
data
# Out:
#             USDVND_close  XBRUSD_close  XAUUSD_close  VN_close  10y_yield
# date
# 1979-12-27           NaN           NaN    515.500000       NaN        NaN
# 1979-12-28           NaN           NaN    512.000000       NaN        NaN
# 1980-01-01           NaN           NaN    512.000000       NaN        NaN
# 1980-01-02           NaN           NaN    559.750000       NaN        NaN
# 1980-01-03           NaN           NaN    634.250000       NaN        NaN
# ...                  ...           ...           ...       ...        ...
# 2022-04-07       22858.0    103.290001   1932.170044   1502.35      2.667
# 2022-04-08       22862.0    104.089996   1945.849976   1482.00      2.745
# 2022-04-10           NaN           NaN   1944.699951       NaN        NaN
# 2022-04-11           NaN    100.720001   1953.430054       NaN        NaN
# 2022-04-12       22890.0    106.160004   1955.480000   1455.25      3.000
#
# [10975 rows x 5 columns]
